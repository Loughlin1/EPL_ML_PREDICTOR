# %%
import os
import sys

current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
grandparent_dir = os.path.dirname(parent_dir)  # Add grandparent directory
sys.path.append(grandparent_dir)  # Ensure 'backend' is in the path
from backend.utils.data_processing import load_training_data
from backend.config.paths import FIXTURES_TRAINING_DATA_DIR

# Load data
df = load_training_data(FIXTURES_TRAINING_DATA_DIR)
df.head()
# Out:
#     Wk  Day        Date   Time            Home Score          Away  \
# 0  1.0  Sat  2014-08-16  12:45  Manchester Utd   1–2  Swansea City
# 1  1.0  Sat  2014-08-16  15:00      Stoke City   0–1   Aston Villa
# 2  1.0  Sat  2014-08-16  15:00  Leicester City   2–2       Everton
# 3  1.0  Sat  2014-08-16  15:00             QPR   0–1     Hull City
# 4  1.0  Sat  2014-08-16  15:00        West Ham   0–1     Tottenham
#
#    Attendance                Venue         Referee  Match Report  Notes  xG  \
# 0     75339.0         Old Trafford       Mike Dean  Match Report    NaN NaN
# 1     27478.0       Bet365 Stadium  Anthony Taylor  Match Report    NaN NaN
# 2     31603.0   King Power Stadium       Mike Dean  Match Report    NaN NaN
# 3     17603.0  Loftus Road Stadium    Craig Pawson  Match Report    NaN NaN
# 4     34977.0        Boleyn Ground       Chris Foy  Match Report    NaN NaN
#
#    xG.1
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
